# %%
import pandas as pd

# %%
df = pd.read_csv('stackoverflow/survey_results_public.csv')
pd.set_option('max_column', 85)

people = {
    'first name': ['mohammad', 'mostafa', 'benyamin','ali'],
    'last name': ['daraee', 'dana', 'dana','hasani'],
    'email':['test@gmail.com', 'test3@gmail.com', 'test4@gmail.com', 'ali.hasani@gmail.com']
}

df2 = pd.DataFrame(people)
df.head(3)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
#
#                                           Employment             Country  \
# 0  Independent contractor, freelancer, or self-em...            Slovakia
# 1                                 Student, full-time         Netherlands
# 2                                 Student, full-time  Russian Federation
#
#   US_State UK_Country                                            EdLevel  \
# 0      NaN        NaN  Secondary school (e.g. American high school, G...
# 1      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# ...

# %%
df2
# Out:
#   first name last name                 email
# 0   mohammad    daraee        test@gmail.com
# 1    mostafa      dana       test3@gmail.com
# 2   benyamin      dana       test4@gmail.com
# 3        ali    hasani  ali.hasani@gmail.com

# %%
df['Gender'].value_counts(normalize=True).head(3).round(4) * 100
# Out:
# Man                  90.92
# Woman                 5.01
# Prefer not to say     1.75
# Name: Gender, dtype: float64

# %%
df['ConvertedCompYearly'].median()
# Out:
# 56211.0

# %%
df.describe()     #count: row that is non Nan count but value_count show all
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
df.median()
# Out:
# /var/folders/t4/zdyms2z53151dg_6ktts7gv80000gn/T/ipykernel_653/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# ResponseId             41720.0
# CompTotal              67000.0
# ConvertedCompYearly    56211.0
# dtype: float64

# %%
f = df['Country'].isin(['India', 'Germani'])
df.loc[f, 'OpSys'].value_counts(normalize=True)
# Out:
# Windows                              0.531095
# Linux-based                          0.243609
# MacOS                                0.195059
# Windows Subsystem for Linux (WSL)    0.024227
# Other (please specify):              0.005055
# BSD                                  0.000954
# Name: OpSys, dtype: float64

# %%
df["OpSys"].value_counts(normalize=True) * 100
# Out:
# Windows                              45.330996
# Linux-based                          25.317550
# MacOS                                25.192691
# Windows Subsystem for Linux (WSL)     3.293154
# Other (please specify):               0.690326
# BSD                                   0.175283
# Name: OpSys, dtype: float64

# %%
df['Country'].value_counts(normalize=True).round(4).head(3) * 100
# Out:
# United States of America    18.32
# India                       12.60
# Germany                      6.74
# Name: Country, dtype: float64

# %% [markdown]
# # group

# %%
grp_country = df.groupby(['Country'])
grp_country

# %%
grp_country.get_group('India').head(4)
# Out:
#     ResponseId                              MainBranch          Employment  \
# 8            9          I am a developer by profession  Employed part-time
# 22          23  I am a student who is learning to code  Student, full-time
# 39          40  I am a student who is learning to code  Student, part-time
# 49          50  I am a student who is learning to code  Student, full-time
#
#    Country US_State UK_Country  \
# 8    India      NaN        NaN
# 22   India      NaN        NaN
# 39   India      NaN        NaN
# 49   India      NaN        NaN
#
#                                               EdLevel     Age1stCode  \
# 8        Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 22  Some college/university study without earning ...   5 - 10 years
# 39       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 49  Some college/university study without earning ...  11 - 17 years
#
# ...

# %%
filt = df['Country'] == 'United States of America'
df[filt].head(2) 
# df.loc[filt]
#we can see specefic column value but with group we can use other methode on tha value
# Out:
#    ResponseId                              MainBranch           Employment  \
# 5           6  I am a student who is learning to code   Student, part-time
# 6           7             I code primarily as a hobby  I prefer not to say
#
#                     Country       US_State UK_Country  \
# 5  United States of America        Georgia        NaN
# 6  United States of America  New Hampshire        NaN
#
#                                              EdLevel     Age1stCode  \
# 5       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 6  Secondary school (e.g. American high school, G...  11 - 17 years
#
#                                            LearnCode YearsCode YearsCodePro  \
# 5  Other online resources (ex: videos, blogs, etc...       NaN          NaN
# 6  Other online resources (ex: videos, blogs, etc...         3          NaN
#
#   DevType OrgSize Currency  CompTotal CompFreq  \
# 5     NaN     NaN      NaN        NaN      NaN
# ...

# %%
df[filt, 'ConvertedCompYearly']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/t4/zdyms2z53151dg_6ktts7gv80000gn/T/ipykernel_653/1460092779.py in <module>
# ----> 1 df[filt, 'ConvertedCompYearly']
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# ...

# %%
df[filt]['ConvertedCompYearly']
# Out:
# 5              NaN
# 6              NaN
# 15             NaN
# 36        103000.0
# 37        300000.0
#            ...
# 83427    4300000.0
# 83429          NaN
# 83430     125000.0
# 83434     160500.0
# 83436      90000.0
# Name: ConvertedCompYearly, Length: 15288, dtype: float64

# %%
df.loc[filt, 'ConvertedCompYearly']
# Out:
# 5              NaN
# 6              NaN
# 15             NaN
# 36        103000.0
# 37        300000.0
#            ...
# 83427    4300000.0
# 83429          NaN
# 83430     125000.0
# 83434     160500.0
# 83436      90000.0
# Name: ConvertedCompYearly, Length: 15288, dtype: float64

# %%
df[filt]['OpSys'].value_counts(normalize=True).round(4) * 100
# Out:
# Windows                              38.24
# MacOS                                35.65
# Linux-based                          22.18
# Windows Subsystem for Linux (WSL)     2.77
# Other (please specify):               0.98
# BSD                                   0.18
# Name: OpSys, dtype: float64

# %%
# group function can combine all value for every group
(grp_country['OpSys'].value_counts(normalize=True)*100).round(2)
# Out:
# Country      OpSys
# Afghanistan  Windows                              45.90
#              Linux-based                          29.51
#              MacOS                                 9.84
#              Other (please specify):               9.84
#              BSD                                   3.28
#                                                   ...
# Zimbabwe     Windows                              55.56
#              Linux-based                          25.00
#              MacOS                                13.89
#              Other (please specify):               2.78
#              Windows Subsystem for Linux (WSL)     2.78
# Name: OpSys, Length: 750, dtype: float64

# %%
os = ['Windows', 'MacOS', 'Linux-based']
os_filt = df['OpSys'].isin(os)
df.loc[os_filt,'Country'].value_counts().nlargest(10)
# Out:
# United States of America                                14664
# India                                                   10167
# Germany                                                  5411
# United Kingdom of Great Britain and Northern Ireland     4297
# Canada                                                   2848
# France                                                   2586
# Brazil                                                   2110
# Netherlands                                              1715
# Poland                                                   1712
# Italy                                                    1614
# Name: Country, dtype: int64

# %%
grp_country['OpSys'].value_counts(normalize=True).loc['India'] * 100
# Out:
# OpSys
# Windows                              53.109500
# Linux-based                          24.360931
# MacOS                                19.505914
# Windows Subsystem for Linux (WSL)     2.422739
# Other (please specify):               0.505532
# BSD                                   0.095383
# Name: OpSys, dtype: float64

# %%
grp_country['ConvertedCompYearly'].median().loc['Germany']
# Out:
# 64859.0

# %%
grp_country['ConvertedCompYearly'].agg(['median', 'mean'])
# Out:
#                                        median          mean
# Country
# Afghanistan                            9792.0  2.794748e+06
# Albania                               15900.0  4.499814e+04
# Algeria                                9875.0  1.446114e+04
# Andorra                               94045.5  8.928200e+04
# Angola                                 9750.0  2.155680e+04
# ...                                       ...           ...
# Venezuela, Bolivarian Republic of...  12000.0  2.246505e+04
# Viet Nam                              12678.0  1.995289e+04
# Yemen                                  3954.0  5.628667e+03
# Zambia                                 9816.0  1.991491e+04
# Zimbabwe                               7200.0  1.141477e+04
#
# [181 rows x 2 columns]

# %%
df[filt]['LanguageHaveWorkedWith'].str.contains('Python')
# Out:
# 5         True
# 6        False
# 15        True
# 36       False
# 37       False
#          ...
# 83427     True
# 83429     True
# 83430     True
# 83434    False
# 83436     True
# Name: LanguageHaveWorkedWith, Length: 15288, dtype: object

# %%
df.loc[filt,'LanguageHaveWorkedWith'].str.contains('Python').value_counts()
# Out:
# True     7975
# False    7158
# Name: LanguageHaveWorkedWith, dtype: int64

# %%
df[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum() # true = 1 , false = 0
# Out:
# 7975

# %%
grp_country['LanguageHaveWorkedWith'].srt.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/t4/zdyms2z53151dg_6ktts7gv80000gn/T/ipykernel_653/1466402986.py in <module>
# ----> 1 grp_country['LanguageHaveWorkedWith'].srt.contains('Python').sum()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'srt'

# %%
grp_country['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
grp_country['LanguageHaveWorkedWith'].count()
# Out:
# Country
# Afghanistan                              61
# Albania                                  71
# Algeria                                  45
# Andorra                                  10
# Angola                                   25
#                                        ...
# Venezuela, Bolivarian Republic of...    104
# Viet Nam                                381
# Yemen                                    19
# Zambia                                   22
# Zimbabwe                                 34
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
answer_lang = grp_country['LanguageHaveWorkedWith'].count()
python_lang = grp_country['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
percent_py = (python_lang / answer_lang) * 100
percent_py
# Out:
# Country
# Afghanistan                             32.786885
# Albania                                 42.253521
# Algeria                                 42.222222
# Andorra                                 40.000000
# Angola                                  20.000000
#                                           ...
# Venezuela, Bolivarian Republic of...    41.346154
# Viet Nam                                45.406824
# Yemen                                   31.578947
# Zambia                                  54.545455
# Zimbabwe                                50.000000
# Name: LanguageHaveWorkedWith, Length: 181, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
answer_lang2 = df['Country'].value_counts()
python_lang2 = grp_country['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
percent_py2 = (python_lang2 / answer_lang2) * 100
percent_py2
# Out:
# Afghanistan                             30.769231
# Albania                                 41.095890
# Algeria                                 41.304348
# Andorra                                 33.333333
# Angola                                  18.518519
#                                           ...
# Venezuela, Bolivarian Republic of...    41.346154
# Viet Nam                                44.818653
# Yemen                                   30.000000
# Zambia                                  54.545455
# Zimbabwe                                47.222222
# Length: 181, dtype: float64

# %%
py_df = pd.concat([answer_lang2, python_lang2, percent_py2], axis='columns')
py_df
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Saint Kitts and Nevis                                     1
# Dominica                                                  1
# Saint Vincent and the Grenadines                          1
# Tuvalu                                                    1
# Papua New Guinea                                          1
#
#                                                     LanguageHaveWorkedWith  \
# United States of America                                              7975
# India                                                                 5233
# ...

# %%
py_df.rename(columns={'LanguageHaveWorkedWith': 'conding lang', 0:  'percentKnowsPython'}, inplace=True)

# %%
py_df.loc['Afghanistan']
# Out:
# Country               65.000000
# conding lang          20.000000
# percentKnowsPython    30.769231
# Name: Afghanistan, dtype: float64

# %%
grp_country['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum()/len(x)*100)
# Out:
# Country
# Afghanistan                             30.769231
# Albania                                 41.095890
# Algeria                                 41.304348
# Andorra                                 33.333333
# Angola                                  18.518519
#                                           ...
# Venezuela, Bolivarian Republic of...    41.346154
# Viet Nam                                44.818653
# Yemen                                   30.000000
# Zambia                                  54.545455
# Zimbabwe                                47.222222
# Name: LanguageHaveWorkedWith, Length: 181, dtype: float64

# %%
py_df2 = pd.concat([answer_lang2, python_lang2], axis='columns')
py_df2
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Saint Kitts and Nevis                                     1
# Dominica                                                  1
# Saint Vincent and the Grenadines                          1
# Tuvalu                                                    1
# Papua New Guinea                                          1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7975
# India                                                                 5233
# ...

# %%
pct_py = grp_country['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum()/len(x)*100)
py_df2['percentKnowsPython'] = pct_py.round(2)
py_df2
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Saint Kitts and Nevis                                     1
# Dominica                                                  1
# Saint Vincent and the Grenadines                          1
# Tuvalu                                                    1
# Papua New Guinea                                          1
#
#                                                     LanguageHaveWorkedWith  \
# United States of America                                              7975
# India                                                                 5233
# ...
