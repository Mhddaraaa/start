# %%
import pandas as pd

# %%
df = pd.read_csv('vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)   # ?
# df

# %%
# df.head(10)

# %%
# df.tail(10)

# %%
person = {
    'first name': 'mohammad',
    'last name': 'daraee',
    'email':'test@gmail.com'
}

person2 = {
    'first name': ['mohammad'],
    'last name': ['daraee'],
    'email':['test@gmail.com']
}

people = {
    'first name': ['mohammad', 'mostafa', 'benyamin',],
    'last name': ['daraee', 'dana', 'dana'],
    'email':['test@gmail.com', 'test3@gmail.com', 'test4@gmail.com']
}

# %%
people['email']
# Out:
# ['test@gmail.com', 'test3@gmail.com', 'test4@gmail.com']

# %%
df2 = pd.DataFrame(people)
df2
# Out:
#   first name last name            email
# 0   mohammad    daraee   test@gmail.com
# 1    mostafa      dana  test3@gmail.com
# 2   benyamin      dana  test4@gmail.com

# %%
df2['email']
# Out:
# 0     test@gmail.com
# 1    test3@gmail.com
# 2    test4@gmail.com
# Name: email, dtype: object

# %%
type(df2['email'])
# Out:
# pandas.core.series.Series

# %%
df2[['last name', 'email']]  # need 2 bracket
# Out:
#   last name            email
# 0    daraee   test@gmail.com
# 1      dana  test3@gmail.com
# 2      dana  test4@gmail.com

# %%
df2.columns
# Out:
# Index(['first name', 'last name', 'email'], dtype='object')

# %%
df2.iloc[0]
# Out:
# first name          mohammad
# last name             daraee
# email         test@gmail.com
# Name: 0, dtype: object

# %%
df2.iloc[[0, 1]]
# Out:
#   first name last name            email
# 0   mohammad    daraee   test@gmail.com
# 1    mostafa      dana  test3@gmail.com

# %%
df2.iloc[[0, 1], [1, 2]]   #[[rows], [colomns]]
# Out:
#   last name            email
# 0    daraee   test@gmail.com
# 1      dana  test3@gmail.com

# %%
df2.loc[0]   #if index change we should use its personal index
# Out:
# first name          mohammad
# last name             daraee
# email         test@gmail.com
# Name: 0, dtype: object

# %%
df2.loc[[0, 1], [ 'email', 'first name']]
# Out:
#              email first name
# 0   test@gmail.com   mohammad
# 1  test3@gmail.com    mostafa

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                                              Wii Sports
# 1                                       Super Mario Bros.
# 2                                          Mario Kart Wii
# 3                                       Wii Sports Resort
# 4                                Pokemon Red/Pokemon Blue
#                                ...
# 16593                  Woody Woodpecker in Crazy Castle 5
# 16594                       Men in Black II: Alien Escape
# 16595    SCORE International Baja 1000: The Official Game
# 16596                                          Know How 2
# 16597                                    Spirits & Spells
# Name: Name, Length: 16598, dtype: object

# %%
filt = df['Name'] == 'Need for Speed: Most Wanted'
df[filt].value_counts()    # count how many times world repeated
# Out:
# Rank   Name                         Platform  Year    Genre   Publisher        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 253    Need for Speed: Most Wanted  PS2       2005.0  Racing  Electronic Arts  2.03      1.79      0.08      0.47         4.37            1
# 499    Need for Speed: Most Wanted  PS3       2012.0  Racing  Electronic Arts  0.71      1.51      0.06      0.61         2.89            1
# 1175   Need for Speed: Most Wanted  X360      2012.0  Racing  Electronic Arts  0.62      0.80      0.01      0.15         1.58            1
# 1532   Need for Speed: Most Wanted  X360      2005.0  Racing  Electronic Arts  1.00      0.17      0.02      0.10         1.29            1
# 1744   Need for Speed: Most Wanted  PSV       2012.0  Racing  Electronic Arts  0.38      0.52      0.01      0.25         1.16            1
# 2007   Need for Speed: Most Wanted  XB        2005.0  Racing  Electronic Arts  0.53      0.46      0.00      0.05         1.04            1
# ...

# %%
len(df['Name'])
# Out:
# 16598

# %%
df[['Name', 'Year']]
# Out:
#                                                    Name    Year
# 0                                            Wii Sports  2006.0
# 1                                     Super Mario Bros.  1985.0
# 2                                        Mario Kart Wii  2008.0
# 3                                     Wii Sports Resort  2009.0
# 4                              Pokemon Red/Pokemon Blue  1996.0
# ...                                                 ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5  2002.0
# 16594                     Men in Black II: Alien Escape  2003.0
# 16595  SCORE International Baja 1000: The Official Game  2008.0
# 16596                                        Know How 2  2010.0
# 16597                                  Spirits & Spells  2003.0
#
# [16598 rows x 2 columns]

# %%
df['Platform'].value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
df.loc[0 ,'Name']
# Out:
# 'Wii Sports'

# %%
df.loc[[0, 1, 2] ,'Name']
# Out:
# 0           Wii Sports
# 1    Super Mario Bros.
# 2       Mario Kart Wii
# Name: Name, dtype: object

# %%
df.loc[0:3 ,'Name']    # sliceing include last value
# Out:
# 0           Wii Sports
# 1    Super Mario Bros.
# 2       Mario Kart Wii
# 3    Wii Sports Resort
# Name: Name, dtype: object

# %%
df.loc[0:3 ,'Name':'Genre']
# Out:
#                 Name Platform    Year     Genre
# 0         Wii Sports      Wii  2006.0    Sports
# 1  Super Mario Bros.      NES  1985.0  Platform
# 2     Mario Kart Wii      Wii  2008.0    Racing
# 3  Wii Sports Resort      Wii  2009.0    Sports

# %%
df2.set_index('email')
# Out:
#                 first name last name
# email
# test@gmail.com    mohammad    daraee
# test3@gmail.com    mostafa      dana
# test4@gmail.com   benyamin      dana

# %%
df2
# Out:
#   first name last name            email
# 0   mohammad    daraee   test@gmail.com
# 1    mostafa      dana  test3@gmail.com
# 2   benyamin      dana  test4@gmail.com

# %%
df2.set_index('email', inplace=True)
df2
# Out:
#                 first name last name
# email
# test@gmail.com    mohammad    daraee
# test3@gmail.com    mostafa      dana
# test4@gmail.com   benyamin      dana

# %%
df2.reset_index()
# Out:
#              email first name last name
# 0   test@gmail.com   mohammad    daraee
# 1  test3@gmail.com    mostafa      dana
# 2  test4@gmail.com   benyamin      dana

# %%
df = pd.read_csv('vgsales.csv', index_col='Rank')  #use any column as indexes----for search in specific column for something
# df

# %%
df3 = pd.read_csv('vgsales.csv', index_col='Platform')
df3
# Out:
#            Rank                                              Name    Year  \
# Platform
# Wii           1                                        Wii Sports  2006.0
# NES           2                                 Super Mario Bros.  1985.0
# Wii           3                                    Mario Kart Wii  2008.0
# Wii           4                                 Wii Sports Resort  2009.0
# GB            5                          Pokemon Red/Pokemon Blue  1996.0
# ...         ...                                               ...     ...
# GBA       16596                Woody Woodpecker in Crazy Castle 5  2002.0
# GC        16597                     Men in Black II: Alien Escape  2003.0
# PS2       16598  SCORE International Baja 1000: The Official Game  2008.0
# DS        16599                                        Know How 2  2010.0
# GBA       16600                                  Spirits & Spells  2003.0
#
# ...

# %%
df3.sort_index() #ascending alphabetic
# Out:
#            Rank                                   Name    Year         Genre  \
# Platform
# 2600       1768                                Kaboom!  1980.0          Misc
# 2600       3942                          River Raid II  1988.0       Shooter
# 2600       2408                                 Enduro  1982.0          Misc
# 2600        240                               Pitfall!  1981.0      Platform
# 2600       4380  Maze Craze: A Game of Cops 'n Robbers     NaN        Action
# ...         ...                                    ...     ...           ...
# XOne       1149                              Far Cry 4  2014.0       Shooter
# XOne       5764                    Disney Infinity 3.0  2015.0        Action
# XOne      16279                          Assetto Corsa  2016.0        Racing
# XOne       2294                Dragon Age: Inquisition  2014.0  Role-Playing
# XOne       3818                        Just Dance 2015  2014.0          Misc
#
# ...

# %%
df3.sort_index(ascending=False)
# Out:
#            Rank                                Name    Year         Genre  \
# Platform
# XOne      15055               NASCAR Heat Evolution  2016.0        Racing
# XOne      12073              Divinity: Original Sin  2015.0  Role-Playing
# XOne      15615                  The Crew: Wild Run  2015.0        Action
# XOne       2974  Plants vs. Zombies: Garden Warfare  2014.0       Shooter
# XOne      12119          Just Dance: Disney Party 2  2015.0        Action
# ...         ...                                 ...     ...           ...
# 2600       4969                             Airlock  1981.0        Action
# 2600       4910                         Laser Blast  1981.0        Action
# 2600       4896                       Bump 'n' Jump  1982.0        Racing
# 2600       3046                  Adventures of Tron  1981.0        Action
# 2600       8760                     Pressure Cooker  1982.0        Action
#
# ...
